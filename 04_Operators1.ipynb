# %% [markdown]
# ---
# ### **Exercise 1: Multiplication of Integers**
#
# **Task**
# Write a function named `print_dog_human_age()` that will:
#
# * Ask the user to input their **dog's age** and assign it to an integer variable called `dog_age`.
# * Calculate the **dog’s age in human years** by multiplying `dog_age` by `7`, storing the result in `dog_human_age`.
# * Print the value of `dog_human_age`.
#
# **Test Input:**
#
# ```
# 4
# ```
#
# **Expected Output:**
#
# ```
# 28
# ```

# %%
def print_dog_human_age():
    dog_age: int(input("Enter the dog's age : "))
    dog_human_age: int(dog_age * 7)
    print(f"The dog's age in human years is : {dog_human_age}")

print_dog_human_age()

# %% [markdown]
# ---
#
# ### **Exercise 2: BIDMAS - Average Calculation**
#
# **Task**
# Write a function named `calculate_average()` that will:
#
# * Ask the user to enter **three separate numbers**: `num1`, `num2`, `num3`.
# * Calculate the **average** using the formula:
#   $(num1 + num2 + num3) / 3$
# * Print the average **rounded to 2 decimal places** using `round()`.
#
# ---
#
# **Hints**
#
# * Use `round(average, 2)` to round the output.
# * Remember to apply **BIDMAS** (Brackets, Indices, Division/Multiplication, Addition/Subtraction) to ensure correct order of operations.
#
# **Test Input:**
#
# ```
# 3
# 5
# 9
# ```
#
# **Expected Output:**
#
# ```
# 5.67
# ```

# %%
def calculate_average():
    num1: int(input("Enter the first number : "))
    num2: int(input("Enter the second number : "))
    num3: int(input("Enter the third number : "))
    average: float((num1 + num2 + num3) / 3)
    print(round(average, 2))

# %% [markdown]
# ---
#
# ### **Exercise 3: BIDMAS – Height Conversion**
#
# **Task**
# Write a function named `calculate_avg_height()` that will:
#
# * Ask the user to **input their height in metres** (as a float).
# * Convert the height to **centimetres** by multiplying it by 100.
# * Print the result as `height_centimeters`.
#
# **Hint**
# Height input is typically a **float** (e.g., 1.67). Ensure you convert it properly before multiplication.
#
# **Test Input:**
#
# ```
# 1.67
# ```
#
# **Expected Output:**
#
# ```
# 167
# ```

# %%
def calculate_avg_height():
    height:float(input("Enter the height in meters : "))
    height_cm: float(height * 100)
    print(f"The height in centimeters is : {height_cm} cm")

# %% [markdown]
# ---
#
# ### **Exercise 4: Float and Formatted Printing – Currency Conversion**
#
# **Task**
# Write a function named `convert_currency()` that will:
#
# * Ask the user to **input an amount in pounds** (without the £ sign).
# * Convert the pounds to euros using the exchange rate: **£1 = €1.16**.
# * Print the result in **euros (€)**, **rounded to 2 decimal places**.
#
# **Important Notes:**
#
# * Ensure the input is handled as a **float**, since currency may include decimals.
# * Do **not** include the `£` sign in input.
# * Use `round(value, 2)` to round the euro amount.
#
# **Test Input:**
#
# ```
# 60
# ```
#
# **Expected Output:**
#
# ```
# €69.6
# ```

# %%
def convert_currency():
    amount_in_pounds: float(input("Enter the amount in pounds : "))
    pound_to_euros:amount_in_pounds*1.16
    print(f"€{round(pound_to_euros, 2)}")

    convert_currency()

# %% [markdown]
# ---
# ### **Exercise 5 - Rounding**
#
# Write a function called `calculate_stats()` which will:
#
# - Assign the numbers `3.145`, `5.6723`, and `9.34` to the variables `num1`, `num2`, and `num3` respectively.
# - Calculate the total of the three numbers, rounded to **2 decimal places**.
# - Calculate the average of the numbers, rounded to **3 decimal places**.
# - Print `total` and `average` in a message that labels them.
#
# **Expected output:**
#
# ```
#
# The total of the three numbers is 18.16
# The average of the three numbers is 6.053
#
# ```
#
# > 💡 *Remember to calculate the average by dividing the total by the quantity of numbers, e.g. `total / 3`*
# ```

# %%
def calculate_stats():
    num1:3.145
    num2:5.6723
    num3:9.34
    total: float(num1 + num2 + num3)
    total2:total.round(2)
    avg: float(total / 3)
    avg2:avg.round(3)
    print(f"Total: {total2}, Average: {avg2}")
    calculate_stats()

# %% [markdown]
# ---
# ## **Exercise 6 - Calculating Volume**
#
# **Scenario:**
# Bill is moving house. He needs to know how much space his cardboard packing boxes have.
#
# **Task:**
# Write a function called `calculate_volume()` which will:
#
# - Assign the values `3.2`, `5.6`, and `7.8` to the variables `base`, `width`, and `height` respectively.
# - Calculate the `box_volume`, rounded to **1 decimal place**.
# - Print the `box_volume`.
#
# **Hint:**
# > 📦 *Volume = base × width × height*
#
# **Expected Output:**
# ```
# 139.8
#
# ```

# %%
def calculate_voloume():
    base:3.2
    width:5.6
    height:7.8
    box_volume: float(base * width * height)
    box_volume:box_volume.round(1)
    print({box_volume})

    calculate_voloume()

# %% [markdown]
# ---
# ### ***Exercise 7 - Calculating with Volumes***
#
# **Scenario:**
# Bill needs to work out how many boxes he will need to pack all his stuff.
#
# **Task:**
# Building on what you did in the last exercise, write a function called `calculate_boxes(base, width, height)` which will:
#
# - Calculate the volume of a box using the `base`, `width`, and `height` supplied as arguments.
# - Ask Bill for the `total_volume` of his stuff.
# - Calculate the total `number_of_boxes` needed using **floor division** and **add one** for any leftover items.
# - Print the `number_of_boxes`.
#
# **Hint:**
# > 📦 Use floor division and add 1 to account for leftover space.
#
# **Test Input:**
# ```
# 1500
#
# ```
#
# **Expected Output:**
# ```
# 11
#
# ```

# %%
def calculate_boxes(base, width, height):
    box_volume = base * width * height
    total_volume = float(input("Enter the total volume of your stuff: "))
    number_of_boxes = total_volume // box_volume + 1
    print(int(number_of_boxes))

# Call example:
# calculate_boxes(3.2, 5.6, 7.8)
calculate_boxes(3.2, 5.6, 7.8)

# %% [markdown]
# ---
# ### ***Exercise 8 - Floor Division***
#
# **Task:**
# Write a function called `calculate_parcel_weight()` which will:
#
# - Ask the user to enter the weights, in kg, of four parcels (`weight1`, `weight2`, `weight3`, `weight4`).
# - Calculate the **total parcel weight** and display it as a **whole number of kg**, always **rounded up**.
# - Print the total `parcel_weight`.
#
# **Hint:**
# > Avoid using `round()` as it may round down.
# > Instead, sum the weights, use **floor division**, then **add one** to ensure that weights like 8.11 kg or 8.77 kg round up to 9 kg.
#
# **Test Inputs:**
# ```
# 1.23
# 2.84
# 1.675
# 3.03
# ```
#
# **Expected Output:**
# ```
# 9kg
# ```

# %%
def calculate_parcel_weight():
    w1:float(input("Enter the weight of the first parcel in kg: "))
    w2:float(input("Enter the weight of the second parcel in kg: "))
    w3:float(input("Enter the weight of the third parcel in kg: "))
    w4:float(input("Enter the weight of the fourth parcel in kg: "))
    total_weight = w1 + w2 + w3 + w4
    parcel_weight = math.ceil(total_weight)
    print(f"{parcel_weight}kg")
calculate_parcel_weight()

# %% [markdown]
# ---
# ### ***Exercise 9 - Modulus***
#
# **Task:**
# Write a function called `get_pm_minutes()` which will:
#
# - Ask the user to enter an afternoon time in **24-hour clock format** (e.g. `1350`).
# - Use **floor division** (`//`) to extract the hour (i.e., divide by 100).
# - Use the **modulus operator** (`%`) to extract the minutes.
# - Convert the hour to **12-hour clock** by subtracting 12 and store the result back in `hour`.
# - Print a message in the format:
#   `"It is {minutes} minutes past {hour} PM"`
#
# **Test Input:**
# ```
# 1350
# ```
# **Expected Output:**
# ```
# It is 50 minutes past 1 PM
#
# ```
# > 💡 *Note:* This code is designed for **afternoon (PM)** times. For morning times (AM), additional conditional logic will be required, which you will explore later.
# ```

# %%
def get_pm_minutes():
    time_24 = int(input("Enter the time in 24-hour format (e.g., 1350): "))
    hour = time_24 // 100
    minutes = time_24 % 100
    hour_12 = hour - 12  # converting to 12-hour format for PM
    print(f"It is {minutes} minutes past {hour_12} PM")

# Test the function
get_pm_minutes()

# %% [markdown]
# ### ***Exercise 10 - How Many Tins of Beans?***
#
# **Task:**
# Write a function called `calculate_tins()` that will calculate how many **tins of beans** can fit in a cardboard box.
#
# **Details:**
#
# - Each bean tin is **11 cm tall** and **8 cm in diameter**.
# - All tins will be **standing upright** and can be **stacked in layers**.
# - Use the **height, width, and depth** of the box supplied in the function’s parameters.
# - Calculate:
#   - The **number of layers** (based on box height and tin height)
#   - The **number of tins per row and column** (based on box width and depth vs tin diameter)
#   - Multiply all three to get the **total number of tins** that can fit.
#
# **Instructions:**
#
# - Ensure all answers are **whole numbers**.
# - Print how many tins will fit in the box.
#
# **Hint:**
# Use floor division to ensure you’re only counting full tins that fit.
#
# **Expected Output:**
# ```
#
# 24 tins will fit in this box
#
# ```

# %%
def calculate_tins(height, width, depth):
    tin_height = 11
    tin_diameter = 8

    layers = height // tin_height
    tins_along_width = width // tin_diameter
    tins_along_depth = depth // tin_diameter

    number_of_tins = layers * tins_along_width * tins_along_depth
    print(f"{number_of_tins} tins will fit in this box")

# Test the function
calculate_tins(24, 50, 18)
