# %% [markdown]
# # Working with Strings

# %% [markdown]
# ---
#
# ### **Exercise 1: Input and Strings**
#
# **Task**:
# Write a function `show_initials()` that:
#
# * Asks the user to input:
#
#   * **first\_name** (string)
#   * **middle\_name** (string)
#   * **surname** (string)
# * Prints the name in the following format:
#   `surname, first_name middle_name`
#
# **Test Input**:
#
# ```
# Peter
# Barry
# Burrows
# ```
#
# **Expected Output**:
#
# ```
# Burrows, Peter Barry
# ```
#
# ---

# %%
def show_initials():
    first_name:str(input('Enter your first name: '))
    middle_name:str(input('Enter your middle name: '))
    surname:str(input('Enter your surname : '))
    print(surname,first_name,middle_name)

    show_initials()

# %% [markdown]
# ---
#
# ### **Exercise 2: Substrings**
#
# **Task**
# Write a function named `show_substring()` that:
#
# * Prompts the user to enter a name (minimum 5 letters).
# * Prints:
#
#   * The **first letter** of the name.
#   * The **fourth letter** of the name.
#
# **Test Input**:
#
# ```
# Bartholomew
# ```
#
# **Expected Output**:
#
# ```
# First letter is B, fourth letter is t
# ```
#
# > 💡 Use indexing: `name[0]` for the first letter, `name[3]` for the fourth letter.
#
# ---

# %%
def show_substring():
    name:str(input('Enter a name of at least 5 letters: '))
    print('The first letter of the name is :  {name[0]} and the fourth letter of the name is : {name[3]}')

    show_substring()

# %% [markdown]
# ---
#
# ### **Exercise 3: Formatting String Output**
#
# **Task**
# Create a function named `show_formatted()` that:
#
# * Prompts the user to input:
#
#   * `house_number`
#   * `road_name`
#   * `town`
#   * `postcode`
# * Displays the full address in a properly formatted layout:
#
# ```
# house_number, road_name
# town
# postcode
# ```
#
# ---
#
# **Test Input**:
#
# ```
# 10
# Old Road
# Chatham
# ME4 1AA
# ```
#
# **Expected Output**:
#
# ```
# 10, Old Road
# Chatham
# ME4 1AA
# ```
#
# > 💡 Use `\n` or multiple `print()` statements to format the output over three lines.
#
# ---

# %%
def show_formatted():
    house_number:str(input('Enter your house number: '))
    road_name:str(input('Enter your road name: '))
    town_name:str(input('Enter your town name: '))
    postcode:str(input('Enter your postcode: '))
    print(f"{house_number}, {road_name}\n{town}\n{postcode}")

    show_formatted()

# %% [markdown]
# ## String functions

# %% [markdown]
# ---
#
# ### **Exercise 4: String Length**
#
# **Task**
# Write a function called `show_namelength()` that:
#
# * Prompts the user to enter a name.
# * Calculates the length of the name using `len()`.
# * Stores the result in a variable named `name_length`.
# * Displays the output in the following format:
#   `name, name_length characters`
#
# ---
#
# **Test Input**:
#
# ```
# William
# ```
#
# **Expected Output**:
#
# ```
# William, 7 characters
# ```
#
# > 💡 Use `len()` to determine the length of the string.
#
# ---

# %%
def show_namelength():
    name:str(input('Enter your name: '))
    name_length:(len(name))
    print(f'{name} ,{name_length} characters')

show_namelength()

# %% [markdown]
# ---
#
# ### **Exercise 5: Case Conversion**
#
# **Task**
# Create a function named `convert_to_capitals()` that:
#
# * Prompts the user to input a name using only lowercase letters.
# * Converts the name to uppercase using the `upper()` method.
# * Stores the result in a variable called `capitalised_name`.
# * Prints the name in all capital letters.
#
# ---
#
# **Test Input**:
#
# ```
# jaswinder
# ```
#
# **Expected Output**:
#
# ```
# JASWINDER
# ```
#
# > 💡 Use `.upper()` to convert a string to uppercase.
#
# ---

# %%
def convert_to_capitals():
    name:str(input('Enter your name in lowercase:'))
    capitalised_name:str(name.upper())
    print(f'Your name in capital letters is: {capitalised_name}')

# %% [markdown]
# ---
#
# ### **Exercise 6: Capitalizing Names**
#
# **Task**
# Write a function named `capitalise_names()` that:
#
# * Prompts the user to input a **name** and a **surname**.
# * Converts both to lowercase, then capitalizes the **first letter** of each using the `.capitalize()` method.
# * Prints the formatted name and surname with only the first letters in uppercase.
#
# ---
#
# **Test Input**:
#
# ```
# benJamIN
# smith
# ```
#
# **Expected Output**:
#
# ```
# Benjamin Smith
# ```
#
# > 💡 Use `.capitalize()` to ensure only the first letter is uppercase and the rest are lowercase.
#
# ---

# %%
def capitalise_names():
    name = input('Enter your name: ')
    surname = input('Enter your surname: ')
    formatted_name = name.capitalize()
    formatted_surname = surname.capitalize()
    print(f'Your name is: {formatted_name} {formatted_surname}')

# Test the function
capitalise_names()

# %% [markdown]
# ---
#
# ### **Exercise 7: Substrings**
#
# **Task**
# Write a function named `show_postcode_letters()` that:
#
# * Prompts the user to enter a **postcode**.
# * Extracts the **first two characters** of the postcode and assigns them to a variable called `postcode_area`.
# * Converts `postcode_area` to **uppercase** and stores it in a variable called `capitalised_area`.
# * Prints the `capitalised_area`.
#
# ---
#
# **Test Input**:
#
# ```
# Me4 6bb
# ```
#
# **Expected Output**:
#
# ```
# ME
# ```
#
# > 💡 Use slicing (`postcode[0:2]`) and the `.upper()` method to extract and convert the desired substring.
#
# ---

# %%
def show_postcode_letters():
    postcode = input("Enter postcode: ")
    postcode_area = postcode[0:2]
    capitalised_area = postcode_area.upper()
    print(capitalised_area)
show_postcode_letters()

# %% [markdown]
# ---
#
# ### **Exercise 8: Floor Division and Slicing**
#
# **Task**
# Write a function named `show_half_word()` that:
#
# * Prompts the user to enter a **word**.
# * Calculates **half the length** of the word using floor division (`//`) and assigns it to `half_length`.
# * Extracts the **first half** of the word and assigns it to `half_word`.
# * Prints the `half_word`.
#
# **Hint**
# Use slicing like: `half_word = word[0:half_length]` to extract the first half.
#
# **Test Input**:
#
# ```
# Runtime
# ```
#
# **Expected Output**:
#
# ```
# Run
# ```

# %%
def show_half_word():
    word:input('Enter a word: ')
    half_length:len(word)//2
    half_word(word[0]:half_length)
    print(f'The first half of the word is: {half_word}')
    show_half_word()

# %% [markdown]
# ---
#
# ### **Exercise 9: String Repetition**
#
# **Task**
# Write a function named `repeat_two_letters()` that will:
#
# * Prompt the user to enter a **word**.
# * Assign the **last two letters** of the word to a variable named `last_two`.
# * Create a string of **5 copies** of `last_two` (using `last_two * 5`) and assign it to a variable called `five_copies`.
# * Print the value of `five_copies`.
#
# **Test Input**:
#
# ```
# Data
# ```
#
# **Expected Output**:
#
# ```
# tatatatata
# ```

# %%
def repeat_two_letters():
    word:str(input('Enter a word:'))
    last_two:str(word[-2:])
    five_copies:str(last_two*5)
    print(f'The last two letters of the word are: {last_two} and they are repeated 5 times: {five_copies}')

# %% [markdown]
# ---
#
# ### **Exercise 10: Converting String to Uppercase for Substring**
#
# **Task**
# Write a function named `convert_to_lower_threeLetters()` that will:
#
# * Assign the value `"january"` to a variable called `month`.
# * Assign the **first three characters** of `month` to a variable called `month_short`.
# * Convert `month_short` to **uppercase** and store it back into `month_short`.
# * Assign the **remaining characters** of `month` to a variable called `month_rest`.
# * Join `month_short` and `month_rest` and store the result back in `month`.
# * Print the final `month`.
#
# **Expected Output**:
#
# ```
# JANuary
# ```

# %%
def convert_to_lower_threeLetters():
    month:'January'
    month_short:month[0:3]
    month_short:month_short.upper()
    month_rest:month[3:]
    month:str(month_short+month_rest)
    print(f'The month is: {month}')
